# %% [markdown]
# # Model V19

# %%
import zipfile
from pathlib import Path

import cv2 as cv
import numpy as np
import onnx
import matplotlib.pyplot as plt
import tensorflow as tf
import tf2onnx
import tqdm
from keras import layers
from keras import models
from keras import callbacks
from keras import losses
from keras import metrics
from keras import optimizers

SKIP_LOADING = False
SKIP_TRAINING = False

if not SKIP_LOADING:
    train_dirs = list((Path.cwd() / 'data').glob('**/train/'))
    test_dirs = list((Path.cwd() / 'data').glob('**/test/'))

    def dataset_file_get_timestamp(file: Path):
        return int(file.stem.split('_')[0])

    def dataset_file_get_steering_angle(file: Path):
        return float(file.stem.split('_')[1].replace('-', '.'))

    def load_data(directory: Path):
        image_paths = []
        steering_angles = []
        # load image paths from the directory
        for file_path in directory.glob('*.png'):
            image_paths.append(file_path)

        # sort images by the timestamp in their filenames
        image_paths.sort(key=dataset_file_get_timestamp)

        # Extract steering angles from filenames
        for path in image_paths:
            steering_angles.append(dataset_file_get_steering_angle(path))
            
        return image_paths, steering_angles

    train_img = []
    train_steer = []
    test_img = []
    test_steer = []

    for test_dir in test_dirs:
        test_img_, test_steer_ = load_data(test_dir)
        test_img += test_img_
        test_steer += test_steer_

    for train_dir in train_dirs:
        train_img_, train_steer_ = load_data(train_dir)
        train_img += train_img_
        train_steer += train_steer_

    BATCH_SIZE = 50
    RAND_SEED = 42

    SHUFFLE_BUFFER_DIVIDER = 10
    PREFETCH_BUFFER_SIZE = tf.data.experimental.AUTOTUNE

    def process_image(image_path):
        img = cv.imread(image_path) 
        hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)
        mask = cv.inRange(hsv, (36, 0, 0), (70, 255,255))
        array = np.array(mask, dtype=np.float32)
        return array

    def dataset_pipeline(features, labels, shuffle):
        global BATCH_SIZE, RAND_SEED, SHUFFLE_BUFFER_DIVIDER, PREFETCH_BUFFER_SIZE

        dataset = tf.data.Dataset.from_tensor_slices((features, labels))
        dataset = dataset.repeat()
        if shuffle:
            print("Shuffling dataset")
            dataset = dataset.shuffle(
                buffer_size=len(features) // SHUFFLE_BUFFER_DIVIDER,
                seed=RAND_SEED
            )
        dataset = dataset.batch(BATCH_SIZE)
        dataset = dataset.prefetch(buffer_size=PREFETCH_BUFFER_SIZE)
        return dataset

    train_data = []
    test_data = []

    tqdm.tqdm.write("Loading training data")
    # load the images and steering angles into numpy arrays
    for path in tqdm.tqdm(train_img):
        train_data.append(process_image(path))

    tqdm.tqdm.write("Loading test data")
    # loading the testing data
    for path in tqdm.tqdm(test_img):
        test_data.append(process_image(path))

    ## create a dataset from the training data by using the dataset pipeline
    print("Creating training dataset")
    train_ds = dataset_pipeline(train_data, train_steer, shuffle=True)

    ## create a dataset from the testing data by using the dataset pipeline
    print("Creating testing dataset")
    test_ds = dataset_pipeline(test_data, test_steer, shuffle=False)

    print("Done!")

model = models.Sequential([
    layers.InputLayer(shape=(66, 100, 1)),
    layers.Conv2D(16, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
    layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.2),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.2),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(16, activation='relu'),
    layers.Dense(1, activation='linear')
])

model.summary()
optimizer = optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mse')

if SKIP_TRAINING:
    exit(0)

## Training parameters
# Specify the various parameters for training
BATCH_DIVIDER = 1
EPOCHS = 150
LEARNING_RATE = 0.001
OPTIMIZER = optimizers.Adam(learning_rate=LEARNING_RATE)
LOSS = losses.MeanSquaredError()
METRICS = metrics.RootMeanSquaredError()

## Reduce Learning Rate (RLR) on Plateau parameters
# Reduce learning rate when validation loss doesn't improve for a
# certain number of epochs
RLR_ON = False
RLR_FACTOR = 0.5
RLR_PATIENCE = 10

## Epoch Logger (EL) parameters
# Reduce the number of epochs printed to console to avoid clutter
EL_ON = False
EL_EPOCHS = 10

class EpochLogger(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        '''Logs training progress every 10 epochs.'''
        if (epoch + 1) % EL_EPOCHS == 0:  # Log every 10 epochs
            print(f"Epoch {epoch+1}: Loss = {logs['loss']:.4f},",
                  f"Val Loss = {logs.get('val_loss', 'N/A'):.4f}")


epoch_logger = EpochLogger()
lr_schedule = callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=RLR_FACTOR,
    patience=RLR_PATIENCE, verbose=0)

callbacks = []
if RLR_ON:
    callbacks.append(lr_schedule)
if EL_ON:
    callbacks.append(epoch_logger)

fit_params = {
    'epochs': EPOCHS,
    'verbose': 0 if EL_ON else 1,
    'callbacks': callbacks,
}

model.compile(optimizer=OPTIMIZER, loss=LOSS)

hist = model.fit(train_ds,
                 steps_per_epoch=len(train_img) // BATCH_SIZE // BATCH_DIVIDER,
                 validation_data=test_ds,
                 validation_steps=len(test_img) // BATCH_SIZE // BATCH_DIVIDER,
                 **fit_params)

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model Mean Squared Error Loss')
plt.ylabel('Mean Squared Error Loss')
plt.xlabel('Epoch')
plt.legend(['Training Set', 'Validation Set'], loc='upper right')
plt.show()

eval_out = model.evaluate(test_ds, steps=50)
print(f"Test loss: {eval_out:.4f}")

def display_results():
    # output the first 16 images and steering angles from the test dataset then predict the steering angle for the images
    fig, axs = plt.subplots(4, 4, figsize=(8, 8))
    # add title to the figure
    fig.suptitle('Training Data')
    fig.tight_layout()

    imgs, steer = next(iter(test_ds)) # get the first batch of images and steering angles

    for i in range(16):
        axs[i//4, i%4].axis('off')
        axs[i//4, i%4].imshow(imgs[i])
        axs[i//4, i%4].set_title(round(steer[i].numpy(), 2))
        predicted = model(imgs[i].numpy().reshape(1, 66, 100, 1)) # predict the steering angle for the image
        axs[i//4, i%4].set_title("Predicted: " + str(np.round(predicted[0][0].numpy(), 2)) + "\n Actual: " + str(round(steer[i].numpy(), 2)))
    plt.tight_layout()
    plt.show()

display_results()
# Out:
# 2025-04-03 02:25:47.958224: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-03 02:25:47.975519: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-04-03 02:25:47.980905: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-03 02:25:48.058578: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading training data
# 100%|██████████| 40000/40000 [00:10<00:00, 3943.94it/s]
# Loading test data
# 100%|██████████| 24000/24000 [00:05<00:00, 4258.36it/s]
# Creating training dataset
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1743672367.157029    1027 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743672367.270773    1027 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743672367.270813    1027 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743672367.274156    1027 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743672367.274192    1027 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743672367.274205    1027 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743672367.447192    1027 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743672367.447244    1027 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-04-03 02:26:07.447251: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1743672367.447279    1027 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-04-03 02:26:07.447295: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9558 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2025-04-03 02:26:07.452576: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1056000000 exceeds 10% of free system memory.
# 2025-04-03 02:26:18.784627: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1056000000 exceeds 10% of free system memory.
# Shuffling dataset
# Creating testing dataset
# Done!
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 64, 98, 16)     │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 32, 49, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 30, 47, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 28, 45, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 14, 22, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 14, 22, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 12, 20, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 10, 18, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 5, 9, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 5, 9, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2880)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       368,768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 449,121 (1.71 MB)
#  Trainable params: 449,121 (1.71 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/150
# 2025-04-03 02:26:26.041576: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1056000000 exceeds 10% of free system memory.
# I0000 00:00:1743672387.979058    1330 service.cc:146] XLA service 0x7f49cc014350 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1743672387.979086    1330 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 4070, Compute Capability 8.9
# 2025-04-03 02:26:28.018519: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-04-03 02:26:28.167110: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
#  75/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1608.9335
# I0000 00:00:1743672391.946154    1330 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 380.6134 - val_loss: 284.4960
# Epoch 2/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 40.6841 - val_loss: 104.7283
# Epoch 3/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 34.5354 - val_loss: 105.2471
# Epoch 4/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 34.4312 - val_loss: 84.4503
# Epoch 5/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 28.3665 - val_loss: 66.4582
# Epoch 6/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 26.0109 - val_loss: 66.2423
# Epoch 7/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 25.2223 - val_loss: 74.9321
# Epoch 8/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 25.5649 - val_loss: 49.7541
# Epoch 9/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 23.1890 - val_loss: 63.9097
# Epoch 10/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 24.7497 - val_loss: 40.8665
# Epoch 11/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 23.5591 - val_loss: 40.4523
# Epoch 12/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 21.8012 - val_loss: 65.1124
# Epoch 13/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 23.9904 - val_loss: 38.9725
# Epoch 14/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 19.0477 - val_loss: 25.8277
# Epoch 15/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 21.1329 - val_loss: 31.4933
# Epoch 16/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 18.6253 - val_loss: 26.4452
# Epoch 17/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 18.3733 - val_loss: 32.7448
# Epoch 18/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 19.6227 - val_loss: 22.9008
# Epoch 19/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 17.9495 - val_loss: 19.3805
# Epoch 20/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 18.1706 - val_loss: 22.3250
# Epoch 21/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 15.8776 - val_loss: 26.5601
# Epoch 22/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 18.8264 - val_loss: 25.5796
# Epoch 23/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 17.9129 - val_loss: 20.7754
# Epoch 24/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 16.5986 - val_loss: 23.3903
# Epoch 25/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 16.6923 - val_loss: 20.6005
# Epoch 26/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 16.5883 - val_loss: 25.0870
# Epoch 27/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 17.0137 - val_loss: 17.3159
# Epoch 28/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 16.0272 - val_loss: 19.9793
# Epoch 29/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 17.0155 - val_loss: 19.9541
# Epoch 30/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 14.2893 - val_loss: 20.7220
# Epoch 31/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 15.2460 - val_loss: 21.8688
# Epoch 32/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 15.0443 - val_loss: 18.2832
# Epoch 33/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 14.6891 - val_loss: 18.2761
# Epoch 34/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 14.1581 - val_loss: 16.3647
# Epoch 35/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 16.2009 - val_loss: 22.8336
# Epoch 36/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 15.4607 - val_loss: 19.9429
# Epoch 37/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 14.8152 - val_loss: 21.5298
# Epoch 38/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 15.1277 - val_loss: 18.2442
# Epoch 39/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 14.2845 - val_loss: 19.3259
# Epoch 40/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 13.5439 - val_loss: 20.1310
# Epoch 41/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 13.6873 - val_loss: 20.2832
# Epoch 42/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 14.4007 - val_loss: 20.1412
# Epoch 43/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 14.0212 - val_loss: 18.3305
# Epoch 44/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 14.6391 - val_loss: 24.0222
# Epoch 45/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 13.5229 - val_loss: 19.5139
# Epoch 46/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.7158 - val_loss: 19.6837
# Epoch 47/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 13.3747 - val_loss: 16.6810
# Epoch 48/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.9825 - val_loss: 18.9858
# Epoch 49/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 13.6059 - val_loss: 20.6299
# Epoch 50/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 13.5139 - val_loss: 15.9464
# Epoch 51/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 14.2214 - val_loss: 15.5529
# Epoch 52/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 13.9673 - val_loss: 15.7945
# Epoch 53/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 14.1904 - val_loss: 15.5740
# Epoch 54/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 13.1685 - val_loss: 16.7792
# Epoch 55/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 13.4430 - val_loss: 20.3859
# Epoch 56/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 14.2408 - val_loss: 20.0269
# Epoch 57/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 13.0028 - val_loss: 19.2307
# Epoch 58/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 13.3553 - val_loss: 16.7858
# Epoch 59/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 13.5787 - val_loss: 14.6700
# Epoch 60/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 13.1414 - val_loss: 18.1634
# Epoch 61/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.7111 - val_loss: 19.3903
# Epoch 62/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 13.1668 - val_loss: 15.6265
# Epoch 63/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 14.7305 - val_loss: 14.3054
# Epoch 64/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.9450 - val_loss: 17.9068
# Epoch 65/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.5356 - val_loss: 17.7836
# Epoch 66/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.9593 - val_loss: 18.2668
# Epoch 67/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 13.2296 - val_loss: 15.8524
# Epoch 68/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 13.5122 - val_loss: 19.4152
# Epoch 69/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.1473 - val_loss: 16.5831
# Epoch 70/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.4683 - val_loss: 19.9076
# Epoch 71/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.4583 - val_loss: 15.5019
# Epoch 72/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 13.4826 - val_loss: 15.2783
# Epoch 73/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.5484 - val_loss: 14.9236
# Epoch 74/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.5914 - val_loss: 16.9940
# Epoch 75/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 14.2340 - val_loss: 17.4894
# Epoch 76/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.8577 - val_loss: 15.9548
# Epoch 77/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 13.9996 - val_loss: 17.0606
# Epoch 78/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.7096 - val_loss: 15.1828
# Epoch 79/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.3071 - val_loss: 15.3158
# Epoch 80/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.7659 - val_loss: 18.2007
# Epoch 81/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 10.7533 - val_loss: 17.1680
# Epoch 82/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 12.0110 - val_loss: 17.1509
# Epoch 83/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.5602 - val_loss: 19.4203
# Epoch 84/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.0526 - val_loss: 18.3403
# Epoch 85/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.0754 - val_loss: 17.8280
# Epoch 86/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.1092 - val_loss: 16.9945
# Epoch 87/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.9483 - val_loss: 15.3213
# Epoch 88/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.7788 - val_loss: 17.2200
# Epoch 89/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.5658 - val_loss: 20.1406
# Epoch 90/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 13.0179 - val_loss: 16.1691
# Epoch 91/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 14.0202 - val_loss: 18.0350
# Epoch 92/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 13.0776 - val_loss: 16.2438
# Epoch 93/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.3237 - val_loss: 17.0612
# Epoch 94/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.1948 - val_loss: 17.7017
# Epoch 95/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.3164 - val_loss: 15.2480
# Epoch 96/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 13.2353 - val_loss: 16.8587
# Epoch 97/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 13.3438 - val_loss: 16.4108
# Epoch 98/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.8969 - val_loss: 18.1181
# Epoch 99/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.7459 - val_loss: 17.2565
# Epoch 100/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.7377 - val_loss: 17.8206
# Epoch 101/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.7015 - val_loss: 14.2104
# Epoch 102/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.8495 - val_loss: 24.0789
# Epoch 103/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.1615 - val_loss: 13.1161
# Epoch 104/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.5290 - val_loss: 15.5175
# Epoch 105/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.1859 - val_loss: 14.2727
# Epoch 106/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.9261 - val_loss: 17.3464
# Epoch 107/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.2093 - val_loss: 16.2462
# Epoch 108/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.8741 - val_loss: 17.5850
# Epoch 109/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.0069 - val_loss: 13.6357
# Epoch 110/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.8623 - val_loss: 15.4929
# Epoch 111/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.9533 - val_loss: 16.2893
# Epoch 112/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.0189 - val_loss: 15.7076
# Epoch 113/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.5194 - val_loss: 14.6384
# Epoch 114/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 11.3986 - val_loss: 14.2339
# Epoch 115/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.1405 - val_loss: 18.6151
# Epoch 116/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.5767 - val_loss: 16.7375
# Epoch 117/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 12.3264 - val_loss: 14.6173
# Epoch 118/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 10.7784 - val_loss: 14.2224
# Epoch 119/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.7057 - val_loss: 16.7591
# Epoch 120/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.0365 - val_loss: 14.0226
# Epoch 121/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.5426 - val_loss: 15.7077
# Epoch 122/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 10.5786 - val_loss: 14.3756
# Epoch 123/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.2543 - val_loss: 16.7654
# Epoch 124/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 10.4944 - val_loss: 12.8915
# Epoch 125/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 10.6341 - val_loss: 14.9610
# Epoch 126/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 10.5954 - val_loss: 15.2446
# Epoch 127/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.6839 - val_loss: 16.2775
# Epoch 128/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.1141 - val_loss: 13.2455
# Epoch 129/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.0644 - val_loss: 17.7785
# Epoch 130/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.4152 - val_loss: 14.7474
# Epoch 131/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.2979 - val_loss: 15.8680
# Epoch 132/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 10.6963 - val_loss: 16.7220
# Epoch 133/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.0932 - val_loss: 14.2065
# Epoch 134/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 10.7053 - val_loss: 15.9780
# Epoch 135/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 10.8457 - val_loss: 16.9622
# Epoch 136/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.8317 - val_loss: 16.1353
# Epoch 137/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 10.4885 - val_loss: 16.3224
# Epoch 138/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 10.9706 - val_loss: 12.8097
# Epoch 139/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 10.6471 - val_loss: 16.0488
# Epoch 140/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.4018 - val_loss: 13.0190
# Epoch 141/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 10.6553 - val_loss: 17.3282
# Epoch 142/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 10.9036 - val_loss: 13.1671
# Epoch 143/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 10.9094 - val_loss: 12.1707
# Epoch 144/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 10.7068 - val_loss: 16.4194
# Epoch 145/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 10.6637 - val_loss: 14.0600
# Epoch 146/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 12.8577 - val_loss: 12.8609
# Epoch 147/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 10.4378 - val_loss: 13.5079
# Epoch 148/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 11.4011 - val_loss: 15.1900
# Epoch 149/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 10.5961 - val_loss: 16.0666
# Epoch 150/150
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 10.6338 - val_loss: 12.9387
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5866
# Test loss: 5.2678
# W0000 00:00:1743672723.223685    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.233981    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.234478    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.234932    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.235379    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.235815    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.236339    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.236790    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.237273    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.237911    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.238359    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.240515    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.241046    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.241530    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.242009    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.243707    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.244231    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.245808    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.247880    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.248432    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.250074    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.251843    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.253908    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.254662    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.256436    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.306960    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.307600    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.308098    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.308946    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.309427    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.309900    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.310384    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.310873    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.311368    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.311842    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.312323    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.312796    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.313346    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.313850    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.314348    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.314869    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.315363    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.315889    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.316455    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.317024    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.317514    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.318050    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.320325    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.321112    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.321674    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.322198    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.322994    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.323504    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.324004    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.324492    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.331698    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.338299    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.338986    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.339488    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.340000    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.340683    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.341278    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.341759    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.342244    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.342731    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.343215    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.343714    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.344202    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.344686    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.345170    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.345649    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.346117    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.346665    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.347208    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.347919    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.348414    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.348907    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.349395    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.349896    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.350501    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.351018    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.351716    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.352165    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.352625    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.353152    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.353631    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.354275    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.359482    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.360017    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.360481    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.360916    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.361344    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.361758    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.362180    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.362603    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.363028    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.363439    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.363865    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.364293    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.364707    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.365135    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.365544    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.366166    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.366703    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.367281    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.367858    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.368447    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.368937    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.369432    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.369938    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.370448    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.370941    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.371547    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.372062    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.372559    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.373160    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.373708    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.374444    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.379787    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.380433    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.380973    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.381746    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.382275    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.382811    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.383349    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.383895    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.384460    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.385006    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.385519    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.386013    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.386513    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.387015    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.387634    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.388402    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.388914    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.389519    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.389995    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.390453    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.390895    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.391344    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.391787    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.392233    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.392659    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.393084    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.393515    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.394031    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.394705    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.395212    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1743672723.395683    1027 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 225
#     221     plt.show()
#     223 display_results()
# --> 225 filename = __file__.split('/')[-1].split('.')[0]
#     226 print(f"Saving model as {filename}.h5")
#     227 model.save(f'{filename}.keras')
#
# NameError: name '__file__' is not defined

# %%
filename = 'v19'
print(f"Saving model as {filename}.h5")
model.save(f'{filename}.keras')
model.save(f'{filename}.h5')
model.output_names = ['output']
input_signature = [tf.TensorSpec([None, 66, 100, 1], tf.float32, name='input')]
onnx_model, _ = tf2onnx.convert.from_keras(model, input_signature=input_signature, opset=13)
onnx.save(onnx_model, filename + ".onnx")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saving model as v19.h5
# I0000 00:00:1743672753.971460    1027 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743672753.972327    1027 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# 2025-04-03 02:32:33.972442: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# I0000 00:00:1743672753.972842    1027 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743672753.972871    1027 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743672753.972885    1027 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743672753.973092    1027 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-04-03 02:32:33.973098: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1743672753.973118    1027 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-04-03 02:32:33.973129: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9558 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# I0000 00:00:1743672754.050985    1027 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743672754.051056    1027 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743672754.051072    1027 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743672754.051216    1027 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-04-03 02:32:34.051234: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1743672754.051265    1027 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-04-03 02:32:34.051278: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9558 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# I0000 00:00:1743672754.076935    1027 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743672754.076975    1027 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# 2025-04-03 02:32:34.077085: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# I0000 00:00:1743672754.078069    1027 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743672754.078103    1027 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743672754.078117    1027 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1743672754.078308    1027 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-04-03 02:32:34.078322: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1743672754.078348    1027 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-04-03 02:32:34.078359: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9558 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
